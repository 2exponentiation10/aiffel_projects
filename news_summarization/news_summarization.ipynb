# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 8-1. 프로젝트: 뉴스기사 요약해보기
# 새로운 데이터셋에 대해서 추상적 요약과 추출적 요약을 모두 해보는 시간을 가져봐요.
#
# 먼저 주요 라이브러리 버전을 확인해 보죠.

# %%
from importlib.metadata import version
import nltk
import tensorflow as tf
import summa
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re
from bs4 import BeautifulSoup

print(nltk.__version__)
print(tf.__version__)
print(pd.__version__)
print(version('summa'))
# Out:
# 3.6.5
# 2.6.0
# 1.3.3
# 1.2.0

# %% [markdown]
# ## Step 1. 데이터 수집하기
# 데이터는 아래 링크에 있는 뉴스 기사 데이터(news_summary_more.csv)를 사용하세요.
#
# sunnysai12345/News_Summary
# 아래의 코드로 데이터를 다운로드할 수 있어요.

# %%
import urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/sunnysai12345/News_Summary/master/news_summary_more.csv", filename="news_summary_more.csv")
data = pd.read_csv('news_summary_more.csv', encoding='iso-8859-1')
data.sample(10)
# Out:
#                                                headlines  \
# 22411  Punjab exempts ex-servicemen from dope test fo...
# 57943  NZ keeper walks home with stump after hitting ...
# 86918  Wearable robot that gives user an extra pair o...
# 78024  22,000 people evacuated after fire at Spain mu...
# 8007   Gold worth Ã¢ÂÂ¹2 cr seized in Chennai; 2 Sou...
# 45119  Politics has snakes, thorns and difficulties: ...
# 35713    China holds largest naval parade in its history
# 92119      North Korea detains third US citizen: Reports
# 56715  BJP, BSP workers clash as UP corporator takes ...
# 89936  BJP slams Amazon for selling decoration with w...
#
#                                                     text
# 22411  Punjab CM Amarinder Singh exempted ex-servicem...
# 57943  New Zealand wicketkeeper Tom Blundell, who sco...
# 86918  Japanese researchers have made robotic limbs t...
# 78024  More than 22,000 people were evacuated on Satu...
# 8007   The Directorate of Revenue Intelligence (DRI) ...
# 45119  Speaking at the inauguration of former CM MG R...
# 35713  China on Thursday conducted its largest naval ...
# 92119  A former Korean-American professor, identified...
# 56715  A scuffle broke out between BJP and BSP worker...
# 89936  Delhi BJP spokesperson Tajinder Pal Singh Bagg...

# %%
print('text 열에서 중복을 배제한 유일한 샘플의 수 :', data['text'].nunique())
print('headlines 열에서 중복을 배제한 유일한 샘플의 수 :', data['headlines'].nunique())
# Out:
# text 열에서 중복을 배제한 유일한 샘플의 수 : 98360
# headlines 열에서 중복을 배제한 유일한 샘플의 수 : 98280

# %%
data.drop_duplicates(subset = ['text'], inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98360

# %%
print(data.isnull().sum())
# Out:
# headlines    0
# text         0
# dtype: int64

# %% [markdown]
# 이 데이터는 기사의 본문에 해당되는 text와 headlines 두 가지 열로 구성되어져 있습니다.
#
# 추상적 요약을 하는 경우에는 text를 본문, headlines를 이미 요약된 데이터로 삼아서 모델을 학습할 수 있어요. 추출적 요약을 하는 경우에는 오직 text열만을 사용하세요.

# %% [markdown]
# ## Step 2. 데이터 전처리하기 (추상적 요약)
# 실습에서 사용된 전처리를 참고하여 각자 필요하다고 생각하는 전처리를 추가 사용하여 텍스트를 정규화 또는 정제해 보세요. 만약, 불용어 제거를 선택한다면 상대적으로 길이가 짧은 요약 데이터에 대해서도 불용어를 제거하는 것이 좋을지 고민해 보세요.

# %%
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

print("정규화 사전의 수: ", len(contractions))
# Out:
# 정규화 사전의 수:  120

# %%
nltk.download('stopwords')
nltk.download('punkt')

print('불용어 개수 :', len(stopwords.words('english') ))
print(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /aiffel/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /aiffel/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 불용어 개수 : 179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 (...) 제거 Ex) my husband (and myself!) for => my husband for
    sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","", sentence) # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence) # m이 3개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah
    
    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
    # 불용어 미제거 (Summary)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens

# %%
temp_text = 'Everything I bought was great, infact I ordered twice and the third ordered was<br />for my mother and father.'
temp_summary = 'Great way to start (or finish) the day!!!'

print("text: ", preprocess_sentence(temp_text))
print("summary:", preprocess_sentence(temp_summary, False))
# Out:
# text:  everything bought great infact ordered twice third ordered wasfor mother father
# summary: great way to start the day

# %%
clean_text = []

clean_text = data['text'].apply(preprocess_sentence)

print("Text 전처리 후 결과: ", clean_text[:5])
# Out:
# Text 전처리 후 결과:  0    saurav kant alumnus upgrad iiit pg program mac...
# 1    kunal shah credit card bill payment platform c...
# 2    new zealand defeated india wickets fourth odi ...
# 3    aegon life iterm insurance plan customers enjo...
# 4    speaking sexual harassment allegations rajkuma...
# Name: text, dtype: object

# %%
# 전체 Summary 데이터에 대한 전처리 : 5분 이상 시간이 걸릴 수 있습니다. 
clean_headlines = []

clean_headlines = data['headlines'].apply(preprocess_sentence)

print("headlines 전처리 후 결과: ", clean_headlines[:5])
# Out:
# headlines 전처리 후 결과:  0     upgrad learner switches career ml al salary hike
# 1     delhi techie wins free food swiggy one year cred
# 2    new zealand end rohit sharma led india match w...
# 3    aegon life iterm insurance plan helps customer...
# 4             known hirani yrs metoo claims true sonam
# Name: headlines, dtype: object

# %%
import numpy as np
data['text'] = clean_text
data['headlines'] = clean_headlines

# 빈 값을 Null 값으로 변환
data.replace('', np.nan, inplace=True)

# %%
data.isnull().sum()
# Out:
# headlines    0
# text         0
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98360

# %% [markdown]
# - 적용하는 경우:
#
#     - 불용어가 제거된 상태의 요약은 더 간결하고 중요한 정보만 포함할 수 있습니다.
#     - 모델이 중요 단어에 집중할 수 있어 요약의 질이 향상될 수 있습니다.
#
# - 적용하지 않는 경우:
#
#     - 불용어가 포함된 상태의 요약은 자연스러운 문장을 유지할 수 있습니다.
#     - 길이가 짧은 요약문에서 불용어를 제거하면 의미 전달이 어려울 수 있습니다.

# %% [markdown]
# ## 길이조정

# %%
# 길이 분포 출력
import matplotlib.pyplot as plt

text_len = [len(s.split()) for s in data['text']]
headlines_len = [len(s.split()) for s in data['headlines']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(headlines_len)))
print('요약의 최대 길이 : {}'.format(np.max(headlines_len)))
print('요약의 평균 길이 : {}'.format(np.mean(headlines_len)))

plt.subplot(1,2,1)
plt.boxplot(text_len)
plt.title('text')
plt.subplot(1,2,2)
plt.boxplot(headlines_len)
plt.title('headlines')
plt.tight_layout()
plt.show()

plt.title('Text')
plt.hist(text_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('headlines')
plt.hist(headlines_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 1
# 텍스트의 최대 길이 : 60
# 텍스트의 평균 길이 : 35.09968483123221
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 13
# 요약의 평균 길이 : 7.136183407889386

# %%
text_max_len = 45
headlines_max_len = 10


def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s.split()) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))


below_threshold_len(text_max_len, data['text'])
below_threshold_len(headlines_max_len,  data['headlines'])
# Out:
# 전체 샘플 중 길이가 45 이하인 샘플의 비율: 1.0
# 전체 샘플 중 길이가 10 이하인 샘플의 비율: 1.0

# %%
data = data[data['text'].apply(lambda x: len(x.split()) <= text_max_len)]
data = data[data['headlines'].apply(lambda x: len(x.split()) <= headlines_max_len)]

# %% [markdown]
# ## Step 3. 어텐션 메커니즘 사용하기 (추상적 요약)
#
# 일반적인 seq2seq보다는 어텐션 메커니즘을 사용한 seq2seq를 사용하는 것이 더 나은 성능을 얻을 수 있어요. 실습 내용을 참고하여 어텐션 메커니즘을 사용한 seq2seq를 설계해 보세요.

# %% [markdown]
# ## 데이터 분리

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Concatenate
from tensorflow.keras.models import Model
from keras.callbacks import EarlyStopping
from tensorflow.keras.layers import AdditiveAttention

# 데이터 준비
data['decoder_input'] = data['headlines'].apply(lambda x : 'sostoken ' + x)
data['decoder_target'] = data['headlines'].apply(lambda x : x + ' eostoken')
data.head()

encoder_input = np.array(data['text'])  # 인코더의 입력
decoder_input = np.array(data['decoder_input'])  # 디코더의 입력
decoder_target = np.array(data['decoder_target'])  # 디코더의 레이블

# %%
# 인덱스 섞기
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)

encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]
# Out:
# [37711   740 31112 ... 14392 36566 54478]

# %%
# 데이터셋 분리
n_of_val = int(len(encoder_input) * 0.2)
print('테스트 데이터의 수 :', n_of_val)
# Out:
# 테스트 데이터의 수 : 19568

# %%
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 78276
# 훈련 레이블의 개수 : 78276
# 테스트 데이터의 개수 : 19568
# 테스트 레이블의 개수 : 19568

# %% [markdown]
# ## 단어 집합(vocabulary) 만들기

# %%
src_tokenizer = Tokenizer() # 토크나이저 정의
src_tokenizer.fit_on_texts(encoder_input_train) # 입력된 데이터로부터 단어 집합 생성

# %%
threshold = 7
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 69189
# 등장 빈도가 6번 이하인 희귀 단어의 수: 47133
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 22056
# 단어 집합에서 희귀 단어의 비율: 68.12210033386809
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 3.4939593454709033

# %%
src_vocab = 8000
src_tokenizer = Tokenizer(num_words=src_vocab) # 단어 집합의 크기를 8,000으로 제한
src_tokenizer.fit_on_texts(encoder_input_train) # 단어 집합 재생성

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train) 
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# 잘 진행되었는지 샘플 출력
print(encoder_input_train[:3])
# Out:
# [[1103, 4137, 29540, 1135, 442, 1738, 407, 636, 45, 15, 1984, 1820, 1, 1205, 911, 7861, 2787, 1979, 2485, 1135, 4, 660, 44571, 1135, 805, 3464, 2787, 1135, 1984, 372, 208, 1965, 12889, 4284, 4253, 347, 3733], [4608, 7035, 1331, 5162, 3664, 116, 4223, 11205, 535, 2216, 2698, 70, 24, 417, 630, 541, 80, 2698, 44572, 654, 6756, 535, 1957, 187, 299, 1217, 1748, 258, 1104, 10448, 412, 5934, 1641, 227, 1], [349, 434, 2636, 3485, 1044, 475, 44573, 1807, 355, 1459, 3813, 18, 263, 1007, 7036, 76, 324, 194, 7036, 461, 1403, 576, 8502, 674, 456, 17383, 83, 1118, 109, 1943, 780, 12890]]

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)

# %%
print(decoder_input_train[:3])
# Out:
# ['sostoken hate muslims love hindus mamata banerjee'
#  'sostoken earth oldest rock found moon samples brought years ago'
#  'sostoken builder ordered refund crore mumbai homebuyers']

# %%
threshold = 6
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 29732
# 등장 빈도가 5번 이하인 희귀 단어의 수: 19519
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 10213
# 단어 집합에서 희귀 단어의 비율: 65.64980492398762
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 5.904977553443247

# %%
tar_vocab = 2000
tar_tokenizer = Tokenizer(num_words=tar_vocab) 
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train) 
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# 잘 변환되었는지 확인
print('input')
print('input ',decoder_input_train[:5])
print('target')
print('decoder ',decoder_target_train[:5])
# Out:
# input
# input  [[1, 1510, 797, 329, 1912, 822], [1, 419, 951, 55, 626, 34, 531], [1, 1132, 13, 27], [1, 1485, 11, 330, 1133], [1, 209, 53, 1674, 46]]
# target
# decoder  [[1510, 797, 329, 1912, 822, 2], [419, 951, 55, 626, 34, 531, 2], [1132, 13, 27, 2], [1485, 11, 330, 1133, 2], [209, 53, 1674, 46, 2]]

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

print('삭제할 훈련 데이터의 개수 :', len(drop_train))
print('삭제할 테스트 데이터의 개수 :', len(drop_test))

encoder_input_train = [sentence for index, sentence in enumerate(encoder_input_train) if index not in drop_train]
decoder_input_train = [sentence for index, sentence in enumerate(decoder_input_train) if index not in drop_train]
decoder_target_train = [sentence for index, sentence in enumerate(decoder_target_train) if index not in drop_train]

encoder_input_test = [sentence for index, sentence in enumerate(encoder_input_test) if index not in drop_test]
decoder_input_test = [sentence for index, sentence in enumerate(decoder_input_test) if index not in drop_test]
decoder_target_test = [sentence for index, sentence in enumerate(decoder_target_test) if index not in drop_test]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 242
# 삭제할 테스트 데이터의 개수 : 70
# 훈련 데이터의 개수 : 78034
# 훈련 레이블의 개수 : 78034
# 테스트 데이터의 개수 : 19498
# 테스트 레이블의 개수 : 19498

# %%
encoder_input_train = pad_sequences(encoder_input_train, maxlen=text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen=text_max_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen=headlines_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen=headlines_max_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen=headlines_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen=headlines_max_len, padding='post')

# %%
vocab_size = len(tokenizer.word_index) + 1

# 모델 설정
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)
encoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout = 0.4)
encoder_output, state_h, state_c  = encoder_lstm(enc_emb)



# 디코더
decoder_inputs = Input(shape=(None,))
dec_emb_layer = Embedding(vocab_size, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs)

# %%
# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()



# 어텐션 층(어텐션 함수)
attn_layer = AdditiveAttention(name='attention_layer')

# 인코더와 디코더의 모든 time step의 hidden state를 어텐션 층에 전달하고 결과를 리턴
attn_out = attn_layer([decoder_outputs, encoder_output])


# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 45)]         0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_10 (Embedding)        (None, 45, 128)      1024000     input_11[0][0]
# __________________________________________________________________________________________________
# embedding_11 (Embedding)        (None, None, 128)    9820672     input_12[0][0]
# __________________________________________________________________________________________________
# lstm_10 (LSTM)                  [(None, 45, 256), (N 394240      embedding_10[0][0]
# __________________________________________________________________________________________________
# lstm_11 (LSTM)                  [(None, None, 256),  394240      embedding_11[0][0]
#                                                                  lstm_10[0][1]
#                                                                  lstm_10[0][2]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, None, 2000)   514000      lstm_11[0][0]
# ==================================================================================================
# Total params: 12,147,152
# Trainable params: 12,147,152
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 45)]         0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_10 (Embedding)        (None, 45, 128)      1024000     input_11[0][0]
# __________________________________________________________________________________________________
# embedding_11 (Embedding)        (None, None, 128)    9820672     input_12[0][0]
# __________________________________________________________________________________________________
# lstm_10 (LSTM)                  [(None, 45, 256), (N 394240      embedding_10[0][0]
# __________________________________________________________________________________________________
# lstm_11 (LSTM)                  [(None, None, 256),  394240      embedding_11[0][0]
#                                                                  lstm_10[0][1]
#                                                                  lstm_10[0][2]
# __________________________________________________________________________________________________
# attention_layer (AdditiveAttent (None, None, 256)    256         lstm_11[0][0]
#                                                                  lstm_10[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 512)    0           lstm_11[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, None, 2000)   1026000     concat_layer[0][0]
# ==================================================================================================
# Total params: 12,659,408
# Trainable params: 12,659,408
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', patience=2, verbose=1)
history = model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, \
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test), \
          batch_size=256, callbacks=[es], epochs=50)
# Out:
# Epoch 1/50
# 305/305 [==============================] - 43s 39ms/step - loss: 3.6296 - val_loss: 3.3643
# Epoch 2/50
# 305/305 [==============================] - 11s 38ms/step - loss: 3.2096 - val_loss: 3.0447
# Epoch 3/50
# 305/305 [==============================] - 12s 38ms/step - loss: 2.9415 - val_loss: 2.8489
# Epoch 4/50
# 305/305 [==============================] - 12s 38ms/step - loss: 2.7705 - val_loss: 2.7255
# Epoch 5/50
# 305/305 [==============================] - 12s 39ms/step - loss: 2.6245 - val_loss: 2.6062
# Epoch 6/50
# 305/305 [==============================] - 12s 39ms/step - loss: 2.4981 - val_loss: 2.5144
# Epoch 7/50
# 305/305 [==============================] - 12s 39ms/step - loss: 2.3917 - val_loss: 2.4430
# Epoch 8/50
# 305/305 [==============================] - 12s 38ms/step - loss: 2.2973 - val_loss: 2.3784
# Epoch 9/50
# 305/305 [==============================] - 12s 38ms/step - loss: 2.2104 - val_loss: 2.3269
# Epoch 10/50
# 305/305 [==============================] - 12s 38ms/step - loss: 2.1321 - val_loss: 2.2806
# Epoch 11/50
# 305/305 [==============================] - 12s 38ms/step - loss: 2.0604 - val_loss: 2.2415
# Epoch 12/50
# 305/305 [==============================] - 12s 39ms/step - loss: 1.9933 - val_loss: 2.2072
# Epoch 13/50
# 305/305 [==============================] - 12s 39ms/step - loss: 1.9331 - val_loss: 2.1798
# Epoch 14/50
# 305/305 [==============================] - 12s 38ms/step - loss: 1.8768 - val_loss: 2.1640
# Epoch 15/50
# 305/305 [==============================] - 12s 38ms/step - loss: 1.8242 - val_loss: 2.1374
# Epoch 16/50
# 305/305 [==============================] - 12s 38ms/step - loss: 1.7754 - val_loss: 2.1222
# Epoch 17/50
# 305/305 [==============================] - 12s 39ms/step - loss: 1.7303 - val_loss: 2.1080
# Epoch 18/50
# 305/305 [==============================] - 12s 38ms/step - loss: 1.6877 - val_loss: 2.1030
# Epoch 19/50
# 305/305 [==============================] - 12s 39ms/step - loss: 1.6483 - val_loss: 2.0898
# Epoch 20/50
# 305/305 [==============================] - 12s 39ms/step - loss: 1.6108 - val_loss: 2.0835
# Epoch 21/50
# 305/305 [==============================] - 12s 39ms/step - loss: 1.5756 - val_loss: 2.0720
# Epoch 22/50
# 305/305 [==============================] - 12s 39ms/step - loss: 1.5415 - val_loss: 2.0694
# Epoch 23/50
# 305/305 [==============================] - 12s 39ms/step - loss: 1.5114 - val_loss: 2.0673
# Epoch 24/50
# 305/305 [==============================] - 12s 39ms/step - loss: 1.4820 - val_loss: 2.0678
# Epoch 25/50
# 305/305 [==============================] - 12s 39ms/step - loss: 1.4535 - val_loss: 2.0647
# Epoch 26/50
# 305/305 [==============================] - 12s 39ms/step - loss: 1.4269 - val_loss: 2.0681
# Epoch 27/50
# 305/305 [==============================] - 12s 39ms/step - loss: 1.4027 - val_loss: 2.0716
# Epoch 00027: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# ## Step 4. 실제 결과와 요약문 비교하기 (추상적 요약)
#
# 원래의 요약문(headlines 열)과 학습을 통해 얻은 추상적 요약의 결과를 비교해 보세요.

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# %%
# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_output, state_h, state_c])

# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)

# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf = attn_layer([decoder_outputs2, decoder_hidden_state_input])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if (sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (headlines_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if (i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# %%
def seq2headlines(input_seq):
    temp = ''
    for i in input_seq:
        if (i != 0 and i != tar_word_to_index['sostoken'] and i != tar_word_to_index['eostoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp.strip()

# %%
for i in range(50, 100):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2headlines(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 : hewlett packard enterprise ceo meg whitman denied reports could next uber ceo speculation future uber become distraction let make clear plan remain company ceo tweeted touted uber potential ceo stepped hp board wednesday
# 실제 요약 : uber ceo ceo
# 예측 요약 :  planning denies reports uber ceo
#
#
# 원문 : two chinese nationals allegedly caught smuggling gold bars worth crore mumbai airport friday night thirty three year old lin hung yu year old hao chun arrived hong kong concealed gold waist pouches cabin bags notably lin earlier refused pass bag metal detector
# 실제 요약 : chinese caught smuggling cr gold airport
# 예측 요약 :  chinese man held gold worth crore
#
#
# 원문 : philippine president rodrigo duterte slammed canada decision halt delivery helicopters philippines saying god canadians stupid get citizens joining isis every right kill citizens duterte added canada halted delivery helicopters emerged might used civilians
# 실제 요약 : canada philippine prez helicopter deal
# 예측 요약 :  philippine prez slams turkey
#
#
# 원문 : nasa studying mission concept involving two miniature satellites called cubesats connected tether could help understand moon got tattoos swirling light dark patterns found across surface concept proposes place pair cm wide satellites connected km long tether lunar orbit one cubesat km surface
# 실제 요약 : find moon got
# 예측 요약 :  nasa probe moon
#
#
# 원문 : bjp chief amit shah thursday said alliance jd intact win parliamentary seats bihar next year lok sabha elections shah met bihar cm jd chief nitish kumar breakfast reportedly meet dinner discuss seat sharing shah dismissed reports differences infighting
# 실제 요약 : alliance nitish win ls seats amit shah
# 예측 요약 :  bjp announces seats bihar polls
#
#
# 원문 : yoga guru ramdev said unemployment big issue country centre state governments enough tackle problem garibi aur bharat mata ke par kalank hai added
# 실제 요약 : centre states much ramdev
# 예측 요약 :  film needs ramdev
#
#
# 원문 : speaking row national awards year old best actor winner riddhi sen said five years line people remember award received however added happened created demarcation appreciated president ram nath kovind presented awards ceremony took place last week
# 실제 요약 : one got national award
# 예측 요약 :  best award
#
#
# 원문 : main tu bhi first song ranbir kapoor sonam kapoor starrer sanju released sonu nigam sunidhi chauhan sung composed music director duo rohan rohan lyrics puneet sharma directed rajkumar hirani film also stars paresh rawal manisha koirala vicky kaushal dia mirza
# 실제 요약 : song sanju released
# 예측 요약 :  ranbir kapoor starrer sanju hits theatres
#
#
# 원문 : french police arrested two men marseille suspicion planning imminent violent attack seized guns bomb making materials subsequent raids reports said islamic state flag reportedly found home one suspects comes first round french presidential elections scheduled april
# 실제 요약 : french police bomb making ahead elections
# 예측 요약 :  arrested german
#
#
# 원문 : us federal judge monday rejected requests president donald trump personal lawyer michael cohen look documents seized cohen fbi prosecutors examine judge said might appoint independent lawyer review records fbi seized several documents including payments pornstar stormy daniels
# 실제 요약 : judge rejects trump bid seized fbi
# 예측 요약 :  trump lawyer lawyer
#
#
# 원문 : technology giant apple offering users refund warranty iphone battery replacements last year apple said refund issued electronic funds transfer credit card used payment earlier company reduced replacement cost warranty batteries iphone models beyond
# 실제 요약 : apple iphone battery
# 예측 요약 :  apple confirms iphone
#
#
# 원문 : mangalore pub attack accused acquitted monday related alleged attack around sri ram sene activists group men women pub accusing women dancing wearing western clothes loose morals activists assaulted dragged hair
# 실제 요약 : attack case
# 예측 요약 :  attack attack
#
#
# 원문 : according reports real life couple amitabh bachchan jaya bachchan seen playing married couple upcoming film film directed shoojit sircar amitabh jaya previously worked together various films together including kabhi khushi kabhie gham silsila chupke chupke abhimaan among others
# 실제 요약 : big play married couple upcoming film report
# 예측 요약 :  amitabh bachchan star together report
#
#
# 원문 : germany biggest lender deutsche bank last month accidentally sent reported billion exchange part daily dealings derivatives amount bank market capitalisation billion landed account deutsche rse ag clearinghouse deutsche bank spokesperson said error identified within minutes rectified
# 실제 요약 : bank accidentally sent billion exchange
# 예측 요약 :  bank loses billion ipo
#
#
# 원문 : congress president rahul gandhi allotted seat sixth row republic day parade alongside ghulam nabi azad leader opposition rajya sabha congress termed move petty politics rahul said bothered sitting bjp president amit shah allotted front row seat along lk advani
# 실제 요약 : rahul gandhi th row seat day
# 예측 요약 :  rahul gandhi th day
#
#
# 원문 : personal identities crore people across world exposed via various data breaches crore identities leaked year ago study internet security firm symantec found us experienced number data breaches india witnessed th number breaches maximum breaches took place malware containing emails
# 실제 요약 : cr people via data breach
# 예측 요약 :  data people cr every year
#
#
# 원문 : actor rajinikanth cancelled upcoming meeting fans chennai stating would difficult take individual pictures fans meet added planned group photographs fans expressed disappointment idea five day meet scheduled april planned four districts nnn
# 실제 요약 : cannot take pic fan rajinikanth meet
# 예측 요약 :  fans fans fans fans
#
#
# 원문 : uk said august wikileaks founder julian assange extradited left ecuador london embassy ecuador top government attorney salvador said assange sought asylum ecuador london embassy avoid extradition sweden accused multiple sexual assaults sweden dropped charges assange last year
# 실제 요약 : uk said top
# 예측 요약 :  uk uk
#
#
# 원문 : air india employees union met niti aayog arvind panagariya demanded government waive airline debt instead selling private player expressing concerns employees demanded salary dues cleared air india privatised notably government given principle approval disinvestment air india
# 실제 요약 : air india debt instead selling workers union
# 예측 요약 :  air india staff union min
#
#
# 원문 : islamic state infiltrated iraqi spies relay necessary information prevent attacks iraq interior minister qasim al said government sometimes allows bombs explode evacuating civilians isis know networks added said fake casualty numbers announced protect informants
# 실제 요약 : isis prevent attacks minister
# 예측 요약 :  attacks isis attacks iraq
#
#
# 원문 : irrfan khan saba qamar starrer hindi medium earned crore within two weeks release china third bollywood film release country aamir khan secret superstar salman khan bajrangi bhaijaan hindi medium earned crore domestic market
# 실제 요약 : hindi china times india
# 예측 요약 :  aamir khan cr hindi film
#
#
# 원문 : bombay high court ruled favour jimmy sheirgill starrer veerey ki wedding sonam kapoor starrer veere di wedding judge find misuse deceit given story cast different said director ashu trikha earlier anil kapoor moved court stop makers jimmy film using title
# 실제 요약 : hc rules ki wedding title row
# 예측 요약 :  wedding ranveer wedding
#
#
# 원문 : religious affairs minister laxmi narayan chaudhary claimed lord hanuman jat stating jo kisi ke mein pair dale wo jat hota hai added hanuman got trouble poking nose people affairs makes jat reportedly samajwadi party bsp congress mlcs protested statement legislative council
# 실제 요약 : lord claims religious minister
# 예측 요약 :  minister
#
#
# 원문 : sister one two nuns missionaries charity arrested ranchi police charges child trafficking confessed crime saying sold two babies said know adding gave away one child free
# 실제 요약 : sold
# 예측 요약 :  teen held child
#
#
# 원문 : maintaining woman choice love one force love somebody supreme court asked cannot women live peace country sc made statement hearing appeal man sentenced seven years allegedly teasing compelling year old girl commit suicide
# 실제 요약 : cannot women live peace india asks supreme court
# 예측 요약 :  woman love cannot love sc
#
#
# 원문 : hearing petitions validity engineering courses offered four deemed universities correspondence supreme court friday invalidated engineering degrees awarded universities since court however said students academic session could regain degrees clear examination held aicte within two attempts
# 실제 요약 : sc cancels via since
# 예측 요약 :  sc
#
#
# 원문 : billionaire elon musk bought shares electric automaker tesla worth million according filings earlier may musk bought million worth company shares musk company largest shareholder owns million shares worth billion according reports
# 실제 요약 : elon musk buys million worth tesla stock
# 예측 요약 :  elon musk worth million
#
#
# 원문 : defence research development organisation developed nutritious protein rich food armed forces deployed high altitude areas food items include chicken biscuits protein rich mutton bar tulsi bar among others defence minister arun jaitley said developing products technologies transferred various industries bulk production
# 실제 요약 : develops bars forces
# 예측 요약 :  food
#
#
# 원문 : government monday submitted details regarding pricing negotiations purchase rafale jets france dassault crore sealed cover supreme court government made public redacted version document said government role selection indian offset partner
# 실제 요약 : govt price details rafale cover sc
# 예측 요약 :  govt rejects rafale
#
#
# 원문 : man raped eight year old girl slit throat arrested madhya pradesh mandsaur thursday within hours police girl found pool blood near school currently hospital accused hanged want justice daughter said girl father
# 실제 요약 : man raped year old held within hrs
# 예측 요약 :  man rapes year old girl madhya pradesh
#
#
# 원문 : indian railways installed plastic bottle crushers vadodara railway station gujarat credit people paytm wallet upon disposing bottles people enter mobile number machine dropping bottles following money credited move aims reduce plastic waste station
# 실제 요약 : people get guj station
# 예측 요약 :  railways stations online
#
#
# 원문 : amazon backed startup north unveiled pair smart glasses uses holographic display technology called glasses connect phones via bluetooth small projector projects data weather time wearer eyes glasses also connected amazon digital assistant alexa respond users asking information
# 실제 요약 : amazon backed startup built
# 예측 요약 :  smart smart speaker
#
#
# 원문 : song sexy barbie girl arbaaz khan sunny leone starrer tera intezaar cleared delhi high court word barbie replaced baby film makers sued mattel inc manufacturer barbie dolls using word barbie song without company permission
# 실제 요약 : girl song changed baby
# 예측 요약 :  sunny daughter
#
#
# 원문 : turkmenistan state media released video showing president gurbanguly berdimuhamedov dressed commando outfit firing targets automatic rifle picking one weapons presented head state demonstrated precision aim served evidence high level military preparedness state news agency said
# 실제 요약 : video prez action hero
# 예측 요약 :  releases video
#
#
# 원문 : australian football club western sydney wanderers new construction stadium stands steepest angle thereby making world steepest stadium stadium capacity ready april costing around crore construct german football league bundesliga also stadiums stands tilt
# 실제 요약 : world stadium
# 예측 요약 :  football stadium stadium stadium
#
#
# 원문 : snapdeal reportedly talks five merchant bankers including sbi caps kotak mahindra capital go ipo second half snapdeal said appointed credit suisse special advisor share sale report comes days snapdeal ceo kunal bahl wrote employees asking prepare ipo
# 실제 요약 : snapdeal talks sbi others ipo report
# 예측 요약 :  snapdeal may buy stake india
#
#
# 원문 : video showing chief trust rajasthan barmer dragging mentally unsound woman hair kicking surfaced online accused said despite given food woman kept coming back trust runs free food facility wherein reimbursed per meal municipal authorities government scheme
# 실제 요약 : video shows trust chief woman hair
# 예측 요약 :  woman made card
#
#
# 원문 : man girlfriend sued us state hawaii claiming false missile alert received cellphones earlier year caused heart attack james shields felt painful burning chest calling loved ones following alert lawsuit said undergo emergency surgery
# 실제 요약 : man sues false missile alert caused heart attack
# 예측 요약 :  man sues man gun
#
#
# 원문 : flipkart founders sachin binny bansal may pay capital gains tax selling company shares us based walmart according tax experts deal would taxable india since substantial value singapore registered flipkart shares derived india noted walmart flipkart deal confirmed softbank ceo masayoshi son wednesday
# 실제 요약 : founders pay capital tax post flipkart sale report
# 예측 요약 :  walmart flipkart must tax walmart walmart
#
#
# 원문 : board online marketplace snapdeal reportedly accepted bigger rival flipkart revised takeover offer million comes reports suggested snapdeal rejected flipkart million offer earlier month flipkart offer said include snapdeal marketplace business unicommerce snapdeal owned app freecharge logistics arm vulcan express
# 실제 요약 : snapdeal board approves flipkart mn bid report
# 예측 요약 :  snapdeal offers snapdeal flipkart reports
#
#
# 원문 : least civilians killed syria raqqa city since june us backed syrian forces began offensive expel islamic state syrian observatory human rights said deceased include children women forces said militants killed seven others captured day offensive
# 실제 요약 : killed us backed syrian isis
# 예측 요약 :  syria kills isis syria
#
#
# 원문 : former google executive joined us based ride hailing startup lyft executive vice president engineering lead team engineers work lyft passion excited join said led team behind google display video apps advertising products worked google search infrastructure
# 실제 요약 : ex google executive joins lead
# 예측 요약 :  uber hires ex google ceo
#
#
# 원문 : several staff selection commission exam aspirants launched protests seeking cbi probe alleged question paper leak mass cheating protests began screenshots question paper circulated online leading cancellation exams however ssc chairman ashim khurana said protests instigated coaching institutes vested interests
# 실제 요약 : delhi
# 예측 요약 :  cbse paper leak leak paper leak
#
#
# 원문 : australia former captain steve smith suspended international cricket picked two wickets caribbean premier action says modelled former pakistan captain shahid afridi trying base action shahid afridi actually bloke played long time terrific leg spinner smith said
# 실제 요약 : steve smith wickets shahid afridi like action
# 예측 요약 :  ex pak captain suspended smith
#
#
# 원문 : rajasthan congress chief sachin pilot said party recent win election seats bjp ruled rajasthan shown tide sentiments congress favour complete rejection vasundhara raje government bjp rajasthan bjp blatantly tried polarise communalise elections pilot added
# 실제 요약 : raj show congress sachin pilot
# 예측 요약 :  congress defeat rajasthan congress
#
#
# 원문 : nafter congress leader shashi tharoor used word rodomontade slamming people trolling writing style twitter user wrote wow trolling user tweeted clarification needs clarification another posted colonial hangover tweets read rodomontade new farrago take us two days learn pronounce word
# 실제 요약 : tharoor paid tweets user
# 예측 요약 :  twitter users tharoor
#
#
# 원문 : ex india cricketer jacob martin shifted general ward icu ventilator nearly month following road accident wherein severely injured lungs martin wife mentioned chances jacob hospital two months bcci csk various cricketers provided financial assistance martin treatment
# 실제 요약 : ex cricketer month
# 예측 요약 :  singh passes away
#
#
# 원문 : speaking indian feminist judgments project workshop supreme court justice dy chandrachud said apply feminist principles one nothing giving effect substance equality constitution chandrachud added say judges could call feminist judges judges objectively decide basis facts
# 실제 요약 : sc judge
# 예측 요약 :  nothing sc
#
#
# 원문 : us president donald trump claimed unaware son donald trump jr meeting russian lawyer june last year trump son met lawyer allegedly offered damaging information trump presidential rival hillary clinton part russia support father trump also defended son disclosures meeting
# 실제 요약 : know son meeting russian lawyer trump
# 예측 요약 :  trump son lawyer son russian lawyer
#
#
# 원문 : group researchers across india relook science technology innovations happened ancient india harappan civilisation use modern times researchers claim technologies time stone beading crafts production indus ceramic technologies metal metallurgy still used
# 실제 요약 : researchers technology use
# 예측 요약 :  india

# %% [markdown]
# ## Step 5. Summa을 이용해서 추출적 요약해보기
# 추상적 요약은 추출적 요약과는 달리 문장의 표현력을 다양하게 가져갈 수 있지만, 추출적 요약에 비해서 난이도가 높아요. 반대로 말하면 추출적 요약은 추상적 요약에 비해 난이도가 낮고 기존 문장에서 문장을 꺼내오는 것이므로 잘못된 요약이 나올 가능성이 낮아요.
#
# Summa의 summarize를 사용하여 추출적 요약을 해보세요.

# %%
import requests
from summa.summarizer import summarize

text = requests.get('http://rare-technologies.com/the_matrix_synopsis.txt').text

print(text[:1500])
# Out:
# The screen is filled with green, cascading code which gives way to the title, The Matrix.
#
# A phone rings and text appears on the screen: "Call trans opt: received. 2-19-98 13:24:18 REC: Log>" As a conversation takes place between Trinity (Carrie-Anne Moss) and Cypher (Joe Pantoliano), two free humans, a table of random green numbers are being scanned and individual numbers selected, creating a series of digits not unlike an ordinary phone number, as if a code is being deciphered or a call is being traced.
#
# Trinity discusses some unknown person. Cypher taunts Trinity, suggesting she enjoys watching him. Trinity counters that "Morpheus (Laurence Fishburne) says he may be 'the One'," just as the sound of a number being selected alerts Trinity that someone may be tracing their call. She ends the call.
#
# Armed policemen move down a darkened, decrepit hallway in the Heart O' the City Hotel, their flashlight beam bouncing just ahead of them. They come to room 303, kick down the door and find a woman dressed in black, facing away from them. It's Trinity. She brings her hands up from the laptop she's working on at their command.
#
# Outside the hotel a car drives up and three agents appear in neatly pressed black suits. They are Agent Smith (Hugo Weaving), Agent Brown (Paul Goddard), and Agent Jones (Robert Taylor). Agent Smith and the presiding police lieutenant argue. Agent Smith admonishes the policeman that they were given specific orders to contact the agents first, for their

# %%
print('headlines:')
print(summarize(text, ratio=0.005))
# Out:
# headlines:
# Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.
# Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.
